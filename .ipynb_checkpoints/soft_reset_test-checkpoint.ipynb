# %%
from utils.helper import  *
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# read all trials
n_trials = 14
n_iter = 20
f_dir = '/home/crslab/Documents/diagnostic_data/stiff_test/'
all_trials = list()
for i in range(1,n_trials+1):
    for j in range(1,n_iter+1):
        if (i == 1) & (j == 20):
            continue
        fname = f_dir + f"stiff_trial{i}_{j}.tact"
        temp_df = read_tac_file(fname)
        temp_df = temp_df[temp_df.taxel != 0]
        temp_df = temp_df.assign(iteration = j)
        temp_df = temp_df.assign(trial = i)
        temp_df = temp_df.assign(order = i%2)
        all_trials.append(temp_df)

# %%
df = pd.concat(all_trials)

# %%
def map_to_finger(taxel_id):
    if (taxel_id <= 39) & (taxel_id >=1):
        return 'left_finger'
    else :
        return 'right_finger'

df = df.assign(finger_type = df.taxel.apply(map_to_finger))

# %%
df.head()
# Out:
#    isNeg  taxel      time  iteration  trial  order  finger_type
# 0      0     11  0.000000          1      1      1  left_finger
# 1      0     38  0.000030          1      1      1  left_finger
# 2      1     38  0.000048          1      1      1  left_finger
# 3      1     38  0.000063          1      1      1  left_finger
# 4      0     38  0.015651          1      1      1  left_finger

# %%
count_df = df.groupby(['iteration', 'trial', 'order']).count().reset_index()

# %%
count_df.head()
# Out:
#    iteration  trial  order  isNeg  taxel  time  finger_type
# 0          1      1      1   5581   5581  5581         5581
# 1          1      2      0   5913   5913  5913         5913
# 2          1      3      1   5821   5821  5821         5821
# 3          1      4      0   5673   5673  5673         5673
# 4          1      5      1   5990   5990  5990         5990

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.barplot(ax=ax, x = 'trial', y='time', hue='order', data=count_df)
ax.set_ylim([5400,6400])
ax.set_ylabel('Total spike count')
plt.show()

# %% [markdown]
# ### Thoughts: TODO
# 1.
# 2.

# %%
count_df = df.groupby(['iteration', 'trial', 'order', 'isNeg']).count().reset_index()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,8))
sns.barplot(ax=ax[0], x = 'trial', y='time', hue='order',  data=count_df[count_df.isNeg==0])
ax[0].set_ylim([2400,3000])
ax[0].set_ylabel('Positive spike count')
sns.barplot(ax=ax[1], x = 'trial', y='time', hue='order',  data=count_df[count_df.isNeg==1])
ax[1].set_ylim([2900,3400])
ax[1].set_ylabel('Negative spike count')
plt.show()

# %%
count_df = df.groupby(['iteration', 'trial', 'order', 'finger_type']).count().reset_index()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,8))
sns.barplot(ax=ax[0], x = 'trial', y='time', hue='order',  data=count_df[count_df.finger_type=='left_finger'])
ax[0].set_ylim([3800,4700])
ax[0].set_ylabel('Left finger total spike count')
sns.barplot(ax=ax[1], x = 'trial', y='time', hue='order',  data=count_df[count_df.finger_type=='right_finger'])
ax[1].set_ylim([1500, 1900])
ax[1].set_ylabel('Right finger total count')
plt.show()

# %%
count_df = df.groupby(['iteration', 'trial', 'order', 'finger_type', 'isNeg']).count().reset_index()

# %%
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(15,16))

left_finger_mask = (count_df.finger_type=='left_finger')
right_finger_maks = ~left_finger_mask
negative_mask = (count_df.isNeg == 1)
positive_mask = ~negative_mask

sns.barplot(ax=ax[0], x = 'trial', y='time', hue='order',  data=count_df[left_finger_mask & positive_mask])
ax[0].set_ylim([1600,2200])
ax[0].set_ylabel('Left finger positive spike count')
sns.barplot(ax=ax[1], x = 'trial', y='time', hue='order',  data=count_df[left_finger_mask & negative_mask])
ax[1].set_ylim([2000, 2600])
ax[1].set_ylabel('Left finger negative spike count')

sns.barplot(ax=ax[2], x = 'trial', y='time', hue='order',  data=count_df[right_finger_maks & positive_mask])
ax[2].set_ylim([600,900])
ax[2].set_ylabel('Right finger positive spike count')
sns.barplot(ax=ax[3], x = 'trial', y='time', hue='order',  data=count_df[right_finger_maks & negative_mask])
ax[3].set_ylim([800, 1200])
ax[3].set_ylabel('Right finger negative spike count')

plt.show()
