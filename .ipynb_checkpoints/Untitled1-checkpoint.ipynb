# %%
import pandas as pd

# %%
rbtq.head()
# Out:
#        time_s    time_ns  c1  c2  c3  c4  c5  target  current  c6
# 0  1604830630  251638889   1   1   3   3   0       0        3   0
# 1  1604830630  259916067   1   1   3   0   0     255        3   1
# 2  1604830630  267246961   1   1   3   0   0     255        3   2
# 3  1604830630  275228023   1   1   3   0   0     255        3   2
# 4  1604830630  283251047   1   1   3   0   0     255        4   3

# %%
rbtq = rbtq.assign(time = rbtq.time_s+rbtq.time_ns/1e-9)

# %%
rbtq.head()
# Out:
#        time_s    time_ns  c1  c2  c3  c4  c5  target  current  c6          time
# 0  1604830630  251638889   1   1   3   3   0       0        3   0  2.516389e+17
# 1  1604830630  259916067   1   1   3   0   0     255        3   1  2.599161e+17
# 2  1604830630  267246961   1   1   3   0   0     255        3   2  2.672470e+17
# 3  1604830630  275228023   1   1   3   0   0     255        3   2  2.752280e+17
# 4  1604830630  283251047   1   1   3   0   0     255        4   3  2.832510e+17

# %%
rbtq[['time', 'target', 'current']]
# Out:
#               time  target  current
# 0     2.516389e+17       0        3
# 1     2.599161e+17     255        3
# 2     2.672470e+17     255        3
# 3     2.752280e+17     255        3
# 4     2.832510e+17     255        4
# ...            ...     ...      ...
# 1417  2.313249e+17       0        3
# 1418  2.393990e+17       0        3
# 1419  2.539010e+17       0        3
# 1420  2.618761e+17       0        3
# 1421  2.713251e+17       0        3
#
# [1422 rows x 3 columns]

# %%
def read_robotiq(fname):
    rbtq = pd.read_csv(fname, names=['time_s', 'time_ns', 'c1', 'c2', 'c3', 'c4', 'c5', 'target', 'current', 'c6'], sep=' ', index_col=False)

# %%
read_robotiq('diagnostic_data/softness_test/stiff_block_trial1_19.rbtq')
